# %% [markdown]
# <a href="https://colab.research.google.com/github/Annergeticaura/Black-Friday-Analysis/blob/main/Black_Friday_Sales_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('test.csv')

# %%
df.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233599 entries, 0 to 233598
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     233599 non-null  int64
#  1   Product_ID                  233599 non-null  object
#  2   Gender                      233599 non-null  object
#  3   Age                         233599 non-null  object
#  4   Occupation                  233599 non-null  int64
#  5   City_Category               233599 non-null  object
#  6   Stay_In_Current_City_Years  233599 non-null  object
#  7   Marital_Status              233599 non-null  int64
#  8   Product_Category_1          233599 non-null  int64
#  9   Product_Category_2          161255 non-null  float64
#  10  Product_Category_3          71037 non-null   float64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 19.6+ MB

# %%
df.isna().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2             72344
# Product_Category_3            162562
# dtype: int64

# %%
df.dropna()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 4       1000011  P00053842      F  26-35           1             C
# 5       1000013  P00350442      M  46-50           1             C
# 6       1000013  P00155442      M  46-50           1             C
# 7       1000013   P0094542      M  46-50           1             C
# 8       1000015  P00161842      M  26-35           7             A
# ...         ...        ...    ...    ...         ...           ...
# 233584  1006023  P00262242      M  26-35           0             C
# 233586  1006026  P00110742      M  36-45           6             C
# 233588  1006030  P00129842      M  26-35          17             C
# 233591  1006033  P00127642      M  51-55          13             B
# 233596  1006036  P00031842      F  26-35          15             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 4                               1               0                   4
# ...

# %%
df['User_ID'].nunique()
# Out:
# 5891

# %%
df['Product_ID'].nunique()
# Out:
# 3491

# %%
for column in df.columns:
  print(column, ":", df[column].nunique())
# Out:
# User_ID : 5891
# Product_ID : 3491
# Gender : 2
# Age : 7
# Occupation : 21
# City_Category : 3
# Stay_In_Current_City_Years : 5
# Marital_Status : 2
# Product_Category_1 : 18
# Product_Category_2 : 17
# Product_Category_3 : 15

# %%
#Female to Male Ratio
len(df[df['Gender']=='F'])/len(df[df['Gender']=='M'])
# Out:
# 0.328988689893726

# %%
#Pie chart for gender
data=pd.DataFrame({'Ratio': [len(df[df['Gender']=='F']),len(df[df['Gender']=='M'])]}, index=['Female','Male'])
data.plot.pie(y='Ratio',autopct='%0.1f')
# Out:
# <Axes: ylabel='Ratio'>

# %%
df['Age'].unique()
# Out:
# array(['46-50', '26-35', '36-45', '18-25', '51-55', '55+', '0-17'],
#       dtype=object)

# %%
df.groupby('Age').size().plot(kind='pie',autopct='%0.1f',title='Age percentages')
# Out:
# <Axes: title={'center': 'Age percentages'}>

# %%
df.groupby('Age').size().plot(kind='bar',title='Age Percentage Users')
# Out:
# <Axes: title={'center': 'Age Percentage Users'}, xlabel='Age'>

# %%
import seaborn as sns
sns.countplot(x='Age',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
df.groupby('City_Category').size().plot(kind='pie',autopct='%0.1f')
# Out:
# <Axes: >

# %%
#City wise age dist
sns.countplot(x='Age',hue='City_Category',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
df.groupby('Stay_In_Current_City_Years').size().plot(kind='pie',autopct='%0.1f')
# Out:
# <Axes: >

# %%
sns.countplot(x='Stay_In_Current_City_Years',hue='Marital_Status',data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x='Stay_In_Current_City_Years',hue='City_Category',data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.groupby('Occupation').size().plot(kind='pie',autopct='%0.1f',figsize=(10,20))
# Out:
# <Axes: >

# %%
df.groupby('Occupation').nunique()['Product_ID'].sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation').nunique()['Product_ID'].nlargest(10).sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
l=[]
for i in range(len(df)):
  l.append(df['Gender'][i] + "_" + str(df['Marital_Status'][i]))

# %%
df['Marital_Gender']=l

# %%
df.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3 Marital_Gender
# 0                11.0                 NaN            M_1
# 1                 5.0                 NaN            M_0
# ...

# %%
df.groupby('Marital_Gender').size().plot(kind='pie',autopct='%0.1f')
# Out:
# <Axes: >

# %%
sns.countplot(x='Age',hue='Marital_Gender',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x='Product_Category_1',hue='Marital_Gender',data=df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(x='Product_Category_2',hue='Marital_Gender',data=df)
# Out:
# <Axes: xlabel='Product_Category_2', ylabel='count'>

# %%
sns.countplot(x='Product_Category_3',hue='Marital_Gender',data=df)
# Out:
# <Axes: xlabel='Product_Category_3', ylabel='count'>
